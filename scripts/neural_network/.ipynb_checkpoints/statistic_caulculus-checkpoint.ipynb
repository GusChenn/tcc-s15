# %%
from scipy.stats import binom
import matplotlib.pyplot as plt

# Approximated parameters
n = 60
p = 0.7681
x_values = list(range(n + 1))

mean, var = binom.stats(n, p)

dist = [binom.pmf(x, n, p) for x in x_values]

print("x\tP(X = x)")
for i in range(n + 1):
    print(str(x_values[i]) + "\t" + str(dist[i]))

print("mean = " + str(mean))
print("variance = " + str(var))

plt.bar(x_values, dist)
plt.show()
# Out:
# x	P(X = x)
# 0	7.61773480458667e-35
# 1	1.2357658682996228e-32
# 2	9.856377027345283e-31
# 3	5.152086460960483e-29
# 4	1.9849844225978322e-27
# 5	6.010826903392528e-26
# 6	1.4897203714272308e-24
# 7	3.107131060405362e-23
# 8	5.565504663290908e-22
# 9	8.694096996646985e-21
# 10	1.1988193747598798e-19
# 11	1.4732965380045686e-18
# 12	1.6265375668031907e-17
# 13	1.6237571607060896e-16
# 14	1.4738388408419543e-15
# 15	1.2220125500116807e-14
# 16	9.292387099047114e-14
# 17	6.502646484126225e-13
# 18	4.199960352607446e-12
# 19	2.5101517429034026e-11
# 20	1.3912748456499715e-10
# 21	7.164942767721232e-10
# 22	3.4341064073572843e-09
# 23	1.534011461193097e-08
# 24	6.394081723275556e-08
# 25	2.489429150928606e-07
# 26	9.060529174676074e-07
# 27	3.0848056805961612e-06
# 28	9.829757783804417e-06
# 29	2.9326071753470238e-05
# 30	8.193197577543589e-05
# 31	0.00021437398679594318
# 32	0.0005252658912581163
# 33	0.001204987072650492
# 34	0.002587178126573121
# 35	0.005196258290196588
# 36	0.009756349155976052
# 37	0.017110233955225287
# 38	0.0280000807123034
# 39	0.04270477647099647
# 40	0.060617057712997614
# 41	0.07994661631524537
# 42	0.09778303071362031
# 43	0.1106691665440975
# 44	0.11560642734109808
# 45	0.11113440916411742
# 46	0.09798081967367848
# 47	0.07890969086406568
# 48	0.05778186468364061
# 49	0.03825919384948541
# 50	0.022757135304545824
# 51	0.012064421766389558
# 52	0.0056455306983745936
# 53	0.0023039761899725773
# 54	0.0008074978278984811
# 55	0.00023817107651147185
# 56	5.749500193563984e-05
# 57	1.0908733310725683e-05
# 58	1.5255508269788833e-06
# 59	1.3981821766410346e-07
# 60	6.300450549061426e-09
# mean = 43.8
# variance = 11.826
